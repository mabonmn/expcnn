# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import matplotlib.image as mpimg
import tensorflow as tf
import pandas as pd
from scipy.io import arff

# %%
data=arff.loadarff(r"C:/Users/NINANMM.000/OneDrive - University of Cincinnati/Mabon Ninan - STDS Lab/Code/time_series(UZ)/AbnormalHeartbeat/AbnormalHeartbeat_TEST.arff")
Test_Data=pd.DataFrame(data[0])
print(Test_Data)
data=arff.loadarff(r"C:/Users/NINANMM.000/OneDrive - University of Cincinnati/Mabon Ninan - STDS Lab/Code/time_series(UZ)/AbnormalHeartbeat/AbnormalHeartbeat_TRAIN.arff")
Train_Data=pd.DataFrame(data[0])
print(Train_Data)
# Out:
#          att1      att2      att3      att4      att5      att6      att7  \
# 0   -0.000153 -0.000153  0.000061 -0.000061 -0.000092 -0.000488 -0.000061
# 1    0.001587 -0.039398 -0.034058  0.003082  0.074127  0.115234  0.057617
# 2   -0.095703 -0.066528 -0.037842 -0.010498  0.015991  0.041229  0.066071
# 3    0.001617 -0.001068  0.001434  0.005188  0.010376  0.013306  0.016327
# 4   -0.113800 -0.119232 -0.117737 -0.106873 -0.082062 -0.059265 -0.045013
# ..        ...       ...       ...       ...       ...       ...       ...
# 299  0.144806  0.137024  0.121704  0.125153  0.128387  0.114349  0.105469
# 300  0.014587  0.022156  0.028259  0.031158 -0.016174 -0.049255  0.024536
# 301  0.005859  0.004944  0.008026  0.011230  0.010406  0.011597  0.012878
# 302 -0.002380 -0.003601 -0.001709 -0.000702  0.001129 -0.001648  0.000549
# 303  0.000885  0.000732  0.000183  0.001312  0.001373  0.001251  0.001343
#
#          att8      att9     att10  ...   att3045   att3046   att3047  \
# ...

# %%
print(type(Train_Data))
print(Train_Data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (302, 3054)

# %%
Train_Data.dtypes
# Out:
# att1       float64
# att2       float64
# att3       float64
# att4       float64
# att5       float64
#             ...
# att3050    float64
# att3051    float64
# att3052    float64
# att3053    float64
# target      object
# Length: 3054, dtype: object
